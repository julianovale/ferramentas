# %% [markdown]
# <a href="https://colab.research.google.com/github/julianovale/ferramentas/blob/main/LazyPredict.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install lazypredict

# %%
from lazypredict.Supervised import LazyClassifier
from lazypredict.Supervised import LazyRegressor
from sklearn.model_selection import train_test_split
import pandas as pd
from sklearn import datasets

# %% [markdown]
# # Classificação

# %%
df = datasets.load_breast_cancer()
type(df)
# Out:
# sklearn.utils.Bunch

# %%
df2 = pd.DataFrame(df.data, columns=df.feature_names)
df2['target'] = df.target
df2.head()
# Out:
#    mean radius  mean texture  ...  worst fractal dimension  target
# 0        17.99         10.38  ...                     0.12       0
# 1        20.57         17.77  ...                     0.09       0
# 2        19.69         21.25  ...                     0.09       0
# 3        11.42         20.38  ...                     0.17       0
# 4        20.29         14.34  ...                     0.08       0
#
# [5 rows x 31 columns]

# %%
X, y = df.data, df.target

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=12)

# %%
clf = LazyClassifier(predictions=True)
models, predictions = clf.fit(X_train, X_test, y_train, y_test)
models
# Out:
# 100%|██████████| 29/29 [00:01<00:00, 15.89it/s]
#                                Accuracy  ...  Time Taken
# Model                                    ...
# LinearSVC                          0.97  ...        0.03
# LogisticRegression                 0.97  ...        0.04
# Perceptron                         0.97  ...        0.02
# SGDClassifier                      0.96  ...        0.05
# PassiveAggressiveClassifier        0.96  ...        0.02
# RidgeClassifierCV                  0.96  ...        0.04
# RidgeClassifier                    0.96  ...        0.03
# ExtraTreesClassifier               0.96  ...        0.15
# KNeighborsClassifier               0.96  ...        0.02
# XGBClassifier                      0.95  ...        0.24
# QuadraticDiscriminantAnalysis      0.95  ...        0.02
# SVC                                0.95  ...        0.05
# LGBMClassifier                     0.95  ...        0.19
# LinearDiscriminantAnalysis         0.95  ...        0.04
# ...

# %% [markdown]
# # Regression

# %%
boston = datasets.load_boston()

# %%
X, y = boston.data, boston.target

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=12)

# %%
reg = LazyRegressor(predictions=True)
models, predictions = reg.fit(X_train, X_test, y_train, y_test)
models
# Out:
# 100%|██████████| 42/42 [00:03<00:00, 11.97it/s]
#                                Adjusted R-Squared  R-Squared  RMSE  Time Taken
# Model
# ExtraTreesRegressor                          0.88       0.90  2.87        0.21
# RandomForestRegressor                        0.86       0.88  3.19        0.36
# XGBRegressor                                 0.86       0.87  3.20        0.08
# LGBMRegressor                                0.85       0.87  3.22        0.07
# GradientBoostingRegressor                    0.84       0.86  3.34        0.16
# BaggingRegressor                             0.84       0.86  3.38        0.05
# HistGradientBoostingRegressor                0.83       0.85  3.46        0.35
# DecisionTreeRegressor                        0.80       0.83  3.74        0.02
# AdaBoostRegressor                            0.79       0.82  3.83        0.11
# PoissonRegressor                             0.78       0.81  3.92        0.02
# ...
